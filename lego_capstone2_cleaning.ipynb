# %%
import pandas as pd

import numpy as np

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

pd.options.display.max_columns=1000

# %%
#Picking 1 of the Lego tables that has a list of all sets by set_num and theme_id. Just to try the regression.
sets = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/sets.csv')
sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0    00-1             Weetabix Castle  1970       414        471
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
sets['set_num'].str.len()
# Out:
# 0         4
# 1         6
# 2         6
# 3         6
# 4         6
#          ..
# 11668    11
# 11669    12
# 11670    11
# 11671    13
# 11672     7
# Name: set_num, Length: 11673, dtype: int64

# %%
sets['set_num_len'] = sets['set_num'].str.len()
sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6

# %%
sets['name'].str.len()
# Out:
# 0        15
# 1        17
# 2        26
# 3        18
# 4        18
#          ..
# 11668    62
# 11669    17
# 11670    58
# 11671    30
# 11672    35
# Name: name, Length: 11673, dtype: int64

# %%
sets['name_len'] = sets['name'].str.len()
sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len
# 0        15
# 1        17
# 2        26
# 3        18
# 4        18

# %%
#Bring in the themes table so I can put a theme name to the set numbers 
themes = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/themes.csv')
themes.head()
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   2  Arctic Technic        1.0
# 2   3     Competition        1.0
# 3   4  Expert Builder        1.0
# 4   5           Model        1.0

# %%
themes = themes.rename(columns={'id':'theme_id', 'name':'theme_name'})
themes.head()
# Out:
#    theme_id      theme_name  parent_id
# 0         1         Technic        NaN
# 1         2  Arctic Technic        1.0
# 2         3     Competition        1.0
# 3         4  Expert Builder        1.0
# 4         5           Model        1.0

# %%
#parent_id column is not needed
themes = themes.drop('parent_id', axis=1)
themes.head()
# Out:
#    theme_id      theme_name
# 0         1         Technic
# 1         2  Arctic Technic
# 2         3     Competition
# 3         4  Expert Builder
# 4         5           Model

# %%
df = sets.merge(themes, on='theme_id', how='left')
df.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len    theme_name
# 0        15        Castle
# 1        17  Supplemental
# 2        26  Lion Knights
# 3        18  Supplemental
# 4        18  Supplemental

# %%
df.shape
# Out:
# (11673, 8)

# %%
# List of the most used themes
df['theme_id'].value_counts()
# Out:
# 501    246
# 371    240
# 504    219
# 220    216
# 494    192
#       ...
# 279      1
# 531      1
# 44       1
# 124      1
# 607      1
# Name: theme_id, Length: 575, dtype: int64

# %%
# Gear as a theme doesn't really help identify the set - gears can be used in many sets
themes[themes['theme_id'] == 501]
# Out:
#      theme_id theme_name
# 500       501       Gear

# %%
# Supplemental as a theme also doesn't help identify a set.
themes[themes['theme_id'] == 371]
# Out:
#      theme_id    theme_name
# 370       371  Supplemental

# %%
# Duplo is quite different from regular Lego bricks and a duplo brick is easily identifiable to a duplo set.
themes[themes['theme_id'] == 504]
# Out:
#      theme_id theme_name
# 503       504      Duplo

# %%
# City as a theme is rich with many sets. I think this is the one I should use.
themes[themes['theme_id'] == 220]
# Out:
#      theme_id theme_name
# 219       220       City

# %%
df['is_city'] = df['theme_id'] == 220
df.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len    theme_name  is_city
# 0        15        Castle    False
# 1        17  Supplemental    False
# 2        26  Lion Knights    False
# 3        18  Supplemental    False
# 4        18  Supplemental    False

# %%
df[df['theme_id'] == 220]
# Out:
#       set_num                                               name  year  \
# 1798  2824-10     Advent Calendar 2010 City (Day 9) Toy Airplane  2010
# 1799  2824-11  Advent Calendar 2010 City (Day 10) Man with Su...  2010
# 1800  2824-12       Advent Calendar 2010 City (Day 11) Fireplace  2010
# 1801  2824-13  Advent Calendar 2010 City (Day 12) Sled with W...  2010
# 1802  2824-14  Advent Calendar 2010 City (Day 13) Toy Fire Truck  2010
# ...       ...                                                ...   ...
# 8856   7907-5  Advent Calendar 2007 City (Day  4) Constructio...  2007
# 8857   7907-6       Advent Calendar 2007 City (Day  5) Barricade  2007
# 8858   7907-7  Advent Calendar 2007 City (Day  6) Directional...  2007
# 8859   7907-8  Advent Calendar 2007 City (Day  7) Airline Wor...  2007
# 8860   7907-9    Advent Calendar 2007 City (Day  8) Luggage Cart  2007
#
#       theme_id  num_parts  set_num_len  name_len theme_name  is_city
# 1798       220         11            7        46       City     True
# 1799       220          5            7        52       City     True
# 1800       220         13            7        44       City     True
# 1801       220         14            7        57       City     True
# 1802       220         15            7        49       City     True
# ...        ...        ...          ...       ...        ...      ...
# 8856       220          5            6        66       City     True
# 8857       220         12            6        44       City     True
# 8858       220         22            6        51       City     True
# 8859       220          5            6        59       City     True
# 8860       220          9            6        47       City     True
#
# [216 rows x 9 columns]

# %%
df = pd.get_dummies(df, columns=['is_city'])
df.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len    theme_name  is_city_False  is_city_True
# 0        15        Castle              1             0
# 1        17  Supplemental              1             0
# 2        26  Lion Knights              1             0
# 3        18  Supplemental              1             0
# 4        18  Supplemental              1             0

# %%
inventories = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/inventories.csv')
inventories.head()
# Out:
#    id  version set_num
# 0   1        1  7922-1
# 1   3        1  3931-1
# 2   4        1  6942-1
# 3  15        1  5158-1
# 4  16        1   903-1

# %%
inventories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11681 entries, 0 to 11680
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       11681 non-null  int64
#  1   version  11681 non-null  int64
#  2   set_num  11681 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 273.9+ KB

# %%
inventories.shape
# Out:
# (11681, 3)

# %%
df.shape
# Out:
# (11673, 10)

# %%
df = df.merge(inventories, on='set_num', how='left')
df.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len    theme_name  is_city_False  is_city_True      id  version
# 0        15        Castle              1             0  5574.0      1.0
# 1        17  Supplemental              1             0  5087.0      1.0
# 2        26  Lion Knights              1             0  2216.0      1.0
# 3        18  Supplemental              1             0  1414.0      1.0
# 4        18  Supplemental              1             0  4609.0      1.0

# %%
df.shape
# Out:
# (11684, 12)

# %%
df = df.drop('version', axis=1)
df.head()
# Out:
#   set_num                        name  year  theme_id  num_parts  set_num_len  \
# 0    00-1             Weetabix Castle  1970       414        471            4
# 1  0011-2           Town Mini-Figures  1978        84         12            6
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2            6
# 3  0012-1          Space Mini-Figures  1979       143         12            6
# 4  0013-1          Space Mini-Figures  1979       143         12            6
#
#    name_len    theme_name  is_city_False  is_city_True      id
# 0        15        Castle              1             0  5574.0
# 1        17  Supplemental              1             0  5087.0
# 2        26  Lion Knights              1             0  2216.0
# 3        18  Supplemental              1             0  1414.0
# 4        18  Supplemental              1             0  4609.0

# %%
inventory_parts = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/inventory_parts.csv')
inventory_parts.head()
# Out:
#    inventory_id     part_num  color_id  quantity is_spare
# 0             1     48379c01        72         1        f
# 1             1        48395         7         1        f
# 2             1     mcsport6        25         1        f
# 3             1       paddle         0         1        f
# 4             3  11816pr0005        78         1        f

# %%
inventory_parts = inventory_parts.rename(columns={'inventory_id':'id'})
inventory_parts.head()
# Out:
#    id     part_num  color_id  quantity is_spare
# 0   1     48379c01        72         1        f
# 1   1        48395         7         1        f
# 2   1     mcsport6        25         1        f
# 3   1       paddle         0         1        f
# 4   3  11816pr0005        78         1        f

# %%
inventory_parts.shape
# Out:
# (580251, 5)

# %%
inventory_parts['quantity']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 580246    3
# 580247    4
# 580248    4
# 580249    9
# 580250    5
# Name: quantity, Length: 580251, dtype: int64

# %%
colors = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/colors.csv')
colors.head()
# Out:
#    id            name     rgb is_trans
# 0  -1         Unknown  0033B2        f
# 1   0           Black  05131D        f
# 2   1            Blue  0055BF        f
# 3   2           Green  237841        f
# 4   3  Dark Turquoise  008F9B        f

# %%
colors = colors.rename(columns={'id':'color_id', 'name':'color_name'})
colors.head()
# Out:
#    color_id      color_name     rgb is_trans
# 0        -1         Unknown  0033B2        f
# 1         0           Black  05131D        f
# 2         1            Blue  0055BF        f
# 3         2           Green  237841        f
# 4         3  Dark Turquoise  008F9B        f

# %%
colors.shape
# Out:
# (135, 4)

# %%
dfB = inventory_parts.merge(colors, on='color_id', how='left')
dfB.head()
# Out:
#    id     part_num  color_id  quantity is_spare        color_name     rgb  \
# 0   1     48379c01        72         1        f  Dark Bluish Gray  6C6E68
# 1   1        48395         7         1        f        Light Gray  9BA19D
# 2   1     mcsport6        25         1        f            Orange  FE8A18
# 3   1       paddle         0         1        f             Black  05131D
# 4   3  11816pr0005        78         1        f       Light Flesh  F6D7B3
#
#   is_trans
# 0        f
# 1        f
# 2        f
# 3        f
# 4        f

# %%
dfB.shape
# Out:
# (580251, 8)

# %%
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580251 entries, 0 to 580250
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          580251 non-null  int64
#  1   part_num    580251 non-null  object
#  2   color_id    580251 non-null  int64
#  3   quantity    580251 non-null  int64
#  4   is_spare    580251 non-null  object
#  5   color_name  580251 non-null  object
#  6   rgb         580251 non-null  object
#  7   is_trans    580251 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 39.8+ MB

# %%
parts = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/parts.csv')
parts.head()
# Out:
#   part_num                                               name  part_cat_id
# 0   0687b1                        Set 0687 Activity Booklet 1           17
# 1     0901  Baseplate 16 x 30 with Set 080 Yellow House Print            1
# 2     0902  Baseplate 16 x 24 with Set 080 Small White Hou...            1
# 3     0903     Baseplate 16 x 24 with Set 080 Red House Print            1
# 4     0904  Baseplate 16 x 24 with Set 080 Large White Hou...            1

# %%
parts = parts.rename(columns={'name':'part_name'})
parts.head()
# Out:
#   part_num                                          part_name  part_cat_id
# 0   0687b1                        Set 0687 Activity Booklet 1           17
# 1     0901  Baseplate 16 x 30 with Set 080 Yellow House Print            1
# 2     0902  Baseplate 16 x 24 with Set 080 Small White Hou...            1
# 3     0903     Baseplate 16 x 24 with Set 080 Red House Print            1
# 4     0904  Baseplate 16 x 24 with Set 080 Large White Hou...            1

# %%
parts.shape
# Out:
# (25993, 3)

# %%
dfB = dfB.merge(parts, on='part_num', how='left')
dfB.head()
# Out:
#    id     part_num  color_id  quantity is_spare        color_name     rgb  \
# 0   1     48379c01        72         1        f  Dark Bluish Gray  6C6E68
# 1   1        48395         7         1        f        Light Gray  9BA19D
# 2   1     mcsport6        25         1        f            Orange  FE8A18
# 3   1       paddle         0         1        f             Black  05131D
# 4   3  11816pr0005        78         1        f       Light Flesh  F6D7B3
#
#   is_trans                                          part_name  part_cat_id
# 0        f                 Sports Promo Figure Base with Feet         27.0
# 1        f  Sports Promo Snowboard from McDonald's Sports ...         27.0
# 2        f  Sports Promo Figure Head Torso Assembly McDona...         13.0
# 3        f    Sports Promo Paddle from McDonald's Sports Sets         27.0
# 4        f  Minifig Head Modified - Friends - Green Eyes, ...         13.0

# %%
dfB.shape
# Out:
# (580251, 10)

# %%
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580251 entries, 0 to 580250
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           580251 non-null  int64
#  1   part_num     580251 non-null  object
#  2   color_id     580251 non-null  int64
#  3   quantity     580251 non-null  int64
#  4   is_spare     580251 non-null  object
#  5   color_name   580251 non-null  object
#  6   rgb          580251 non-null  object
#  7   is_trans     580251 non-null  object
#  8   part_name    580069 non-null  object
#  9   part_cat_id  580069 non-null  float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 48.7+ MB

# %%
dfB = dfB.drop('is_spare', axis=1)

# %%
dfB = dfB.drop('rgb', axis=1)

# %%
dfB = dfB.drop('part_cat_id', axis=1)
dfB.head()
# Out:
#    id     part_num  color_id  quantity        color_name is_trans  \
# 0   1     48379c01        72         1  Dark Bluish Gray        f
# 1   1        48395         7         1        Light Gray        f
# 2   1     mcsport6        25         1            Orange        f
# 3   1       paddle         0         1             Black        f
# 4   3  11816pr0005        78         1       Light Flesh        f
#
#                                            part_name
# 0                 Sports Promo Figure Base with Feet
# 1  Sports Promo Snowboard from McDonald's Sports ...
# 2  Sports Promo Figure Head Torso Assembly McDona...
# 3    Sports Promo Paddle from McDonald's Sports Sets
# 4  Minifig Head Modified - Friends - Green Eyes, ...

# %%
dfB = pd.get_dummies(dfB, columns=['is_trans'])
dfB.head()
# Out:
#    id     part_num  color_id  quantity        color_name  \
# 0   1     48379c01        72         1  Dark Bluish Gray
# 1   1        48395         7         1        Light Gray
# 2   1     mcsport6        25         1            Orange
# 3   1       paddle         0         1             Black
# 4   3  11816pr0005        78         1       Light Flesh
#
#                                            part_name  is_trans_f  is_trans_t
# 0                 Sports Promo Figure Base with Feet           1           0
# 1  Sports Promo Snowboard from McDonald's Sports ...           1           0
# 2  Sports Promo Figure Head Torso Assembly McDona...           1           0
# 3    Sports Promo Paddle from McDonald's Sports Sets           1           0
# 4  Minifig Head Modified - Friends - Green Eyes, ...           1           0

# %%
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580251 entries, 0 to 580250
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          580251 non-null  int64
#  1   part_num    580251 non-null  object
#  2   color_id    580251 non-null  int64
#  3   quantity    580251 non-null  int64
#  4   color_name  580251 non-null  object
#  5   part_name   580069 non-null  object
#  6   is_trans_f  580251 non-null  uint8
#  7   is_trans_t  580251 non-null  uint8
# dtypes: int64(3), object(3), uint8(2)
# memory usage: 32.1+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11684 entries, 0 to 11683
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   set_num        11684 non-null  object
#  1   name           11684 non-null  object
#  2   year           11684 non-null  int64
#  3   theme_id       11684 non-null  int64
#  4   num_parts      11684 non-null  int64
#  5   set_num_len    11684 non-null  int64
#  6   name_len       11684 non-null  int64
#  7   theme_name     11684 non-null  object
#  8   is_city_False  11684 non-null  uint8
#  9   is_city_True   11684 non-null  uint8
#  10  id             11681 non-null  float64
# dtypes: float64(1), int64(5), object(3), uint8(2)
# memory usage: 935.6+ KB

# %%
dfB['part_name'].isnull().sum()
# Out:
# 182

# %%
dfB[dfB.isnull().any(axis=1)].head()
# Out:
#         id part_num  color_id  quantity         color_name part_name  \
# 1215    56    48002         0         4              Black       NaN
# 8411   234     2476        71         1  Light Bluish Gray       NaN
# 20611  609     3650         7         3         Light Gray       NaN
# 20836  618  rb00164         0         2              Black       NaN
# 20914  621     2476        28         3           Dark Tan       NaN
#
#        is_trans_f  is_trans_t
# 1215            1           0
# 8411            1           0
# 20611           1           0
# 20836           1           0
# 20914           1           0

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11681 entries, 0 to 11683
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   set_num        11681 non-null  object
#  1   name           11681 non-null  object
#  2   year           11681 non-null  int64
#  3   theme_id       11681 non-null  int64
#  4   num_parts      11681 non-null  int64
#  5   set_num_len    11681 non-null  int64
#  6   name_len       11681 non-null  int64
#  7   theme_name     11681 non-null  object
#  8   is_city_False  11681 non-null  uint8
#  9   is_city_True   11681 non-null  uint8
#  10  id             11681 non-null  float64
# dtypes: float64(1), int64(5), object(3), uint8(2)
# memory usage: 935.4+ KB

# %%
dfB = dfB.fillna('None')
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580251 entries, 0 to 580250
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          580251 non-null  int64
#  1   part_num    580251 non-null  object
#  2   color_id    580251 non-null  int64
#  3   quantity    580251 non-null  int64
#  4   color_name  580251 non-null  object
#  5   part_name   580251 non-null  object
#  6   is_trans_f  580251 non-null  uint8
#  7   is_trans_t  580251 non-null  uint8
# dtypes: int64(3), object(3), uint8(2)
# memory usage: 32.1+ MB

# %%
dfB[dfB['part_name'] == 'None']
# Out:
#            id part_num  color_id  quantity         color_name part_name  \
# 1215       56    48002         0         4              Black      None
# 8411      234     2476        71         1  Light Bluish Gray      None
# 20611     609     3650         7         3         Light Gray      None
# 20836     618  rb00164         0         2              Black      None
# 20914     621     2476        28         3           Dark Tan      None
# ...       ...      ...       ...       ...                ...       ...
# 531250  15582     3650         7         8         Light Gray      None
# 533485  15624  rb00164         0         1              Black      None
# 555165  16315    4502w        14         1             Yellow      None
# 556394  16351  rb00164         0         1              Black      None
# 559033  16421     6932       297         1         Pearl Gold      None
#
#         is_trans_f  is_trans_t
# 1215             1           0
# 8411             1           0
# 20611            1           0
# 20836            1           0
# 20914            1           0
# ...            ...         ...
# 531250           1           0
# 533485           1           0
# 555165           1           0
# 556394           1           0
# 559033           1           0
#
# [182 rows x 8 columns]

# %%
df = df.merge(dfB, on='id', how='inner')
df.head()
# Out:
#   set_num             name  year  theme_id  num_parts  set_num_len  name_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4        15
# 1    00-1  Weetabix Castle  1970       414        471            4        15
# 2    00-1  Weetabix Castle  1970       414        471            4        15
# 3    00-1  Weetabix Castle  1970       414        471            4        15
# 4    00-1  Weetabix Castle  1970       414        471            4        15
#
#   theme_name  is_city_False  is_city_True      id part_num  color_id  \
# 0     Castle              1             0  5574.0    29c01         4
# 1     Castle              1             0  5574.0    29c01        15
# 2     Castle              1             0  5574.0    3001a        15
# 3     Castle              1             0  5574.0    3001a         4
# 4     Castle              1             0  5574.0    3001a         1
#
#    quantity color_name                           part_name  is_trans_f  \
# 0         8        Red         Window 1 x 1 x 2 with Glass           1
# 1         6      White         Window 1 x 1 x 2 with Glass           1
# 2        25      White  Brick 2 x 4 without Cross Supports           1
# 3         9        Red  Brick 2 x 4 without Cross Supports           1
# 4         4       Blue  Brick 2 x 4 without Cross Supports           1
#
#    is_trans_t
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df.shape
# Out:
# (580251, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580251 entries, 0 to 580250
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   set_num        580251 non-null  object
#  1   name           580251 non-null  object
#  2   year           580251 non-null  int64
#  3   theme_id       580251 non-null  int64
#  4   num_parts      580251 non-null  int64
#  5   set_num_len    580251 non-null  int64
#  6   name_len       580251 non-null  int64
#  7   theme_name     580251 non-null  object
#  8   is_city_False  580251 non-null  uint8
#  9   is_city_True   580251 non-null  uint8
#  10  id             580251 non-null  float64
#  11  part_num       580251 non-null  object
#  12  color_id       580251 non-null  int64
#  13  quantity       580251 non-null  int64
#  14  color_name     580251 non-null  object
#  15  part_name      580251 non-null  object
#  16  is_trans_f     580251 non-null  uint8
#  17  is_trans_t     580251 non-null  uint8
# dtypes: float64(1), int64(7), object(6), uint8(4)
# memory usage: 68.6+ MB

# %%
df = df.drop('is_city_False', axis=1)
df.head()
# Out:
#   set_num             name  year  theme_id  num_parts  set_num_len  name_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4        15
# 1    00-1  Weetabix Castle  1970       414        471            4        15
# 2    00-1  Weetabix Castle  1970       414        471            4        15
# 3    00-1  Weetabix Castle  1970       414        471            4        15
# 4    00-1  Weetabix Castle  1970       414        471            4        15
#
#   theme_name  is_city_True      id part_num  color_id  quantity color_name  \
# 0     Castle             0  5574.0    29c01         4         8        Red
# 1     Castle             0  5574.0    29c01        15         6      White
# 2     Castle             0  5574.0    3001a        15        25      White
# 3     Castle             0  5574.0    3001a         4         9        Red
# 4     Castle             0  5574.0    3001a         1         4       Blue
#
#                             part_name  is_trans_f  is_trans_t
# 0         Window 1 x 1 x 2 with Glass           1           0
# 1         Window 1 x 1 x 2 with Glass           1           0
# 2  Brick 2 x 4 without Cross Supports           1           0
# 3  Brick 2 x 4 without Cross Supports           1           0
# 4  Brick 2 x 4 without Cross Supports           1           0

# %%
df = df.drop('is_trans_f', axis=1)
df.head()
# Out:
#   set_num             name  year  theme_id  num_parts  set_num_len  name_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4        15
# 1    00-1  Weetabix Castle  1970       414        471            4        15
# 2    00-1  Weetabix Castle  1970       414        471            4        15
# 3    00-1  Weetabix Castle  1970       414        471            4        15
# 4    00-1  Weetabix Castle  1970       414        471            4        15
#
#   theme_name  is_city_True      id part_num  color_id  quantity color_name  \
# 0     Castle             0  5574.0    29c01         4         8        Red
# 1     Castle             0  5574.0    29c01        15         6      White
# 2     Castle             0  5574.0    3001a        15        25      White
# 3     Castle             0  5574.0    3001a         4         9        Red
# 4     Castle             0  5574.0    3001a         1         4       Blue
#
#                             part_name  is_trans_t
# 0         Window 1 x 1 x 2 with Glass           0
# 1         Window 1 x 1 x 2 with Glass           0
# 2  Brick 2 x 4 without Cross Supports           0
# 3  Brick 2 x 4 without Cross Supports           0
# 4  Brick 2 x 4 without Cross Supports           0

# %%
df = df.rename(columns={'name':'set_name'})
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  name_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4        15
# 1    00-1  Weetabix Castle  1970       414        471            4        15
# 2    00-1  Weetabix Castle  1970       414        471            4        15
# 3    00-1  Weetabix Castle  1970       414        471            4        15
# 4    00-1  Weetabix Castle  1970       414        471            4        15
#
#   theme_name  is_city_True      id part_num  color_id  quantity color_name  \
# 0     Castle             0  5574.0    29c01         4         8        Red
# 1     Castle             0  5574.0    29c01        15         6      White
# 2     Castle             0  5574.0    3001a        15        25      White
# 3     Castle             0  5574.0    3001a         4         9        Red
# 4     Castle             0  5574.0    3001a         1         4       Blue
#
#                             part_name  is_trans_t
# 0         Window 1 x 1 x 2 with Glass           0
# 1         Window 1 x 1 x 2 with Glass           0
# 2  Brick 2 x 4 without Cross Supports           0
# 3  Brick 2 x 4 without Cross Supports           0
# 4  Brick 2 x 4 without Cross Supports           0

# %%
df = df.rename(columns={'name_len':'set_name_len'})
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city_True      id part_num  color_id  quantity  \
# 0            15     Castle             0  5574.0    29c01         4         8
# 1            15     Castle             0  5574.0    29c01        15         6
# 2            15     Castle             0  5574.0    3001a        15        25
# 3            15     Castle             0  5574.0    3001a         4         9
# 4            15     Castle             0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans_t
# 0        Red         Window 1 x 1 x 2 with Glass           0
# 1      White         Window 1 x 1 x 2 with Glass           0
# 2      White  Brick 2 x 4 without Cross Supports           0
# 3        Red  Brick 2 x 4 without Cross Supports           0
# 4       Blue  Brick 2 x 4 without Cross Supports           0

# %%
df['theme_name_len'] = df['theme_name'].str.len()
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city_True      id part_num  color_id  quantity  \
# 0            15     Castle             0  5574.0    29c01         4         8
# 1            15     Castle             0  5574.0    29c01        15         6
# 2            15     Castle             0  5574.0    3001a        15        25
# 3            15     Castle             0  5574.0    3001a         4         9
# 4            15     Castle             0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans_t  theme_name_len
# 0        Red         Window 1 x 1 x 2 with Glass           0               6
# 1      White         Window 1 x 1 x 2 with Glass           0               6
# 2      White  Brick 2 x 4 without Cross Supports           0               6
# 3        Red  Brick 2 x 4 without Cross Supports           0               6
# 4       Blue  Brick 2 x 4 without Cross Supports           0               6

# %%
df['part_num_len'] = df['part_num'].str.len()
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city_True      id part_num  color_id  quantity  \
# 0            15     Castle             0  5574.0    29c01         4         8
# 1            15     Castle             0  5574.0    29c01        15         6
# 2            15     Castle             0  5574.0    3001a        15        25
# 3            15     Castle             0  5574.0    3001a         4         9
# 4            15     Castle             0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans_t  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass           0               6
# 1      White         Window 1 x 1 x 2 with Glass           0               6
# 2      White  Brick 2 x 4 without Cross Supports           0               6
# 3        Red  Brick 2 x 4 without Cross Supports           0               6
# 4       Blue  Brick 2 x 4 without Cross Supports           0               6
#
#    part_num_len
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5

# %%
df['color_name_len'] = df['color_name'].str.len()
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city_True      id part_num  color_id  quantity  \
# 0            15     Castle             0  5574.0    29c01         4         8
# 1            15     Castle             0  5574.0    29c01        15         6
# 2            15     Castle             0  5574.0    3001a        15        25
# 3            15     Castle             0  5574.0    3001a         4         9
# 4            15     Castle             0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans_t  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass           0               6
# 1      White         Window 1 x 1 x 2 with Glass           0               6
# 2      White  Brick 2 x 4 without Cross Supports           0               6
# 3        Red  Brick 2 x 4 without Cross Supports           0               6
# 4       Blue  Brick 2 x 4 without Cross Supports           0               6
#
#    part_num_len  color_name_len
# 0             5               3
# 1             5               5
# 2             5               5
# 3             5               3
# 4             5               4

# %%
df['part_name_len'] = df['part_name'].str.len()
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city_True      id part_num  color_id  quantity  \
# 0            15     Castle             0  5574.0    29c01         4         8
# 1            15     Castle             0  5574.0    29c01        15         6
# 2            15     Castle             0  5574.0    3001a        15        25
# 3            15     Castle             0  5574.0    3001a         4         9
# 4            15     Castle             0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans_t  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass           0               6
# 1      White         Window 1 x 1 x 2 with Glass           0               6
# 2      White  Brick 2 x 4 without Cross Supports           0               6
# 3        Red  Brick 2 x 4 without Cross Supports           0               6
# 4       Blue  Brick 2 x 4 without Cross Supports           0               6
#
#    part_num_len  color_name_len  part_name_len
# 0             5               3             27
# 1             5               5             27
# 2             5               5             34
# 3             5               3             34
# 4             5               4             34

# %%
df = df.rename(columns={'is_city_True':'is_city', 'is_trans_t':'is_trans'})
df.head(3)
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city      id part_num  color_id  quantity  \
# 0            15     Castle        0  5574.0    29c01         4         8
# 1            15     Castle        0  5574.0    29c01        15         6
# 2            15     Castle        0  5574.0    3001a        15        25
#
#   color_name                           part_name  is_trans  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass         0               6
# 1      White         Window 1 x 1 x 2 with Glass         0               6
# 2      White  Brick 2 x 4 without Cross Supports         0               6
#
#    part_num_len  color_name_len  part_name_len
# 0             5               3             27
# 1             5               5             27
# 2             5               5             34

# %%
is_train = np.random.rand(df.shape[0]) > 0.1
is_train.sum() / df.shape[0]
# Out:
# 0.8996365366022635

# %%
is_city = df['is_city'].sum() / df.shape[0]
is_city
# Out:
# 0.0031555309684946687

# %%
# List of the most used themes
df['theme_id'].value_counts()
# Out:
# 435    16876
# 494    15757
# 37     13654
# 22     12638
# 169    12203
#        ...
# 289        5
# 498        4
# 18         3
# 530        2
# 368        1
# Name: theme_id, Length: 556, dtype: int64

# %%
themes[themes['theme_id'] == 435]
# Out:
#      theme_id theme_name
# 434       435    Ninjago

# %%
df['is_ninjago'] = df['theme_id'] == 435
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city      id part_num  color_id  quantity  \
# 0            15     Castle        0  5574.0    29c01         4         8
# 1            15     Castle        0  5574.0    29c01        15         6
# 2            15     Castle        0  5574.0    3001a        15        25
# 3            15     Castle        0  5574.0    3001a         4         9
# 4            15     Castle        0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass         0               6
# 1      White         Window 1 x 1 x 2 with Glass         0               6
# 2      White  Brick 2 x 4 without Cross Supports         0               6
# 3        Red  Brick 2 x 4 without Cross Supports         0               6
# 4       Blue  Brick 2 x 4 without Cross Supports         0               6
#
#    part_num_len  color_name_len  part_name_len  is_ninjago
# 0             5               3             27       False
# 1             5               5             27       False
# 2             5               5             34       False
# 3             5               3             34       False
# 4             5               4             34       False

# %%
df[df['theme_id'] == 435]
# Out:
#              set_num                                set_name  year  theme_id  \
# 43327        11909-1  Lego Ninjago: Build Your Own Adventure  2015       435
# 43328        11909-1  Lego Ninjago: Build Your Own Adventure  2015       435
# 43329        11909-1  Lego Ninjago: Build Your Own Adventure  2015       435
# 43330        11909-1  Lego Ninjago: Build Your Own Adventure  2015       435
# 43331        11909-1  Lego Ninjago: Build Your Own Adventure  2015       435
# ...              ...                                     ...   ...       ...
# 580082  TRUNINJAGO-4                      Micro Morro Dragon  2015       435
# 580083  TRUNINJAGO-4                      Micro Morro Dragon  2015       435
# 580084  TRUNINJAGO-4                      Micro Morro Dragon  2015       435
# 580085  TRUNINJAGO-4                      Micro Morro Dragon  2015       435
# 580086  TRUNINJAGO-4                      Micro Morro Dragon  2015       435
#
#         num_parts  set_num_len  set_name_len theme_name  is_city       id  \
# 43327          74            7            38    Ninjago        0   7116.0
# 43328          74            7            38    Ninjago        0   7116.0
# 43329          74            7            38    Ninjago        0   7116.0
# 43330          74            7            38    Ninjago        0   7116.0
# 43331          74            7            38    Ninjago        0   7116.0
# ...           ...          ...           ...        ...      ...      ...
# 580082         29           12            18    Ninjago        0  15797.0
# 580083         29           12            18    Ninjago        0  15797.0
# 580084         29           12            18    Ninjago        0  15797.0
# 580085         29           12            18    Ninjago        0  15797.0
# 580086         29           12            18    Ninjago        0  15797.0
#
#        part_num  color_id  quantity         color_name  \
# 43327     10247        72         2   Dark Bluish Gray
# 43328     11215         0         1              Black
# 43329     11477       288         2         Dark Green
# 43330     14417        72         2   Dark Bluish Gray
# 43331     14418        71         2  Light Bluish Gray
# ...         ...       ...       ...                ...
# 580082    54200         0         1              Black
# 580083    54200        72         4   Dark Bluish Gray
# 580084    59900         0         1              Black
# 580085     6133         0         2              Black
# 580086     6141        36         1          Trans-Red
#
#                                                 part_name  is_trans  \
# 43327   Plate Special 2 x  2 with 1 Pin Hole [Complete...         0
# 43328                               Bracket 5 x 2 x 1 1/3         0
# 43329               Slope Curved 2 x 1 No Studs [1/2 Bow]         0
# 43330     Plate Special 1 x 2 with 5.9mm Centre Side Ball         0
# 43331                   Plate Special 1 x 2 5.9mm End Cup         0
# ...                                                   ...       ...
# 580082               Slope 30° 1 x 1 x 2/3 (Cheese Slope)         0
# 580083               Slope 30° 1 x 1 x 2/3 (Cheese Slope)         0
# 580084                            Cone 1 x 1 [Top Groove]         0
# 580085                                        Dragon Wing         0
# 580086                  Plate Round 1 x 1 with Solid Stud         1
#
#         theme_name_len  part_num_len  color_name_len  part_name_len  \
# 43327                7             5              16             61
# 43328                7             5               5             21
# 43329                7             5              10             37
# 43330                7             5              16             47
# 43331                7             5              17             33
# ...                ...           ...             ...            ...
# 580082               7             5               5             36
# 580083               7             5              16             36
# 580084               7             5               5             23
# 580085               7             4               5             11
# 580086               7             4               9             33
#
#         is_ninjago
# 43327         True
# 43328         True
# 43329         True
# 43330         True
# 43331         True
# ...            ...
# 580082        True
# 580083        True
# 580084        True
# 580085        True
# 580086        True
#
# [16876 rows x 21 columns]

# %%
df = pd.get_dummies(df, columns=['is_ninjago'])
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city      id part_num  color_id  quantity  \
# 0            15     Castle        0  5574.0    29c01         4         8
# 1            15     Castle        0  5574.0    29c01        15         6
# 2            15     Castle        0  5574.0    3001a        15        25
# 3            15     Castle        0  5574.0    3001a         4         9
# 4            15     Castle        0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass         0               6
# 1      White         Window 1 x 1 x 2 with Glass         0               6
# 2      White  Brick 2 x 4 without Cross Supports         0               6
# 3        Red  Brick 2 x 4 without Cross Supports         0               6
# 4       Blue  Brick 2 x 4 without Cross Supports         0               6
#
#    part_num_len  color_name_len  part_name_len  is_ninjago_False  \
# 0             5               3             27                 1
# 1             5               5             27                 1
# 2             5               5             34                 1
# 3             5               3             34                 1
# 4             5               4             34                 1
#
#    is_ninjago_True
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
df = df.drop('is_ninjago_False', axis=1)
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city      id part_num  color_id  quantity  \
# 0            15     Castle        0  5574.0    29c01         4         8
# 1            15     Castle        0  5574.0    29c01        15         6
# 2            15     Castle        0  5574.0    3001a        15        25
# 3            15     Castle        0  5574.0    3001a         4         9
# 4            15     Castle        0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass         0               6
# 1      White         Window 1 x 1 x 2 with Glass         0               6
# 2      White  Brick 2 x 4 without Cross Supports         0               6
# 3        Red  Brick 2 x 4 without Cross Supports         0               6
# 4       Blue  Brick 2 x 4 without Cross Supports         0               6
#
#    part_num_len  color_name_len  part_name_len  is_ninjago_True
# 0             5               3             27                0
# 1             5               5             27                0
# 2             5               5             34                0
# 3             5               3             34                0
# 4             5               4             34                0

# %%
df = df.rename(columns={'is_ninjago_True':'is_ninjago'})
df.head()
# Out:
#   set_num         set_name  year  theme_id  num_parts  set_num_len  \
# 0    00-1  Weetabix Castle  1970       414        471            4
# 1    00-1  Weetabix Castle  1970       414        471            4
# 2    00-1  Weetabix Castle  1970       414        471            4
# 3    00-1  Weetabix Castle  1970       414        471            4
# 4    00-1  Weetabix Castle  1970       414        471            4
#
#    set_name_len theme_name  is_city      id part_num  color_id  quantity  \
# 0            15     Castle        0  5574.0    29c01         4         8
# 1            15     Castle        0  5574.0    29c01        15         6
# 2            15     Castle        0  5574.0    3001a        15        25
# 3            15     Castle        0  5574.0    3001a         4         9
# 4            15     Castle        0  5574.0    3001a         1         4
#
#   color_name                           part_name  is_trans  theme_name_len  \
# 0        Red         Window 1 x 1 x 2 with Glass         0               6
# 1      White         Window 1 x 1 x 2 with Glass         0               6
# 2      White  Brick 2 x 4 without Cross Supports         0               6
# 3        Red  Brick 2 x 4 without Cross Supports         0               6
# 4       Blue  Brick 2 x 4 without Cross Supports         0               6
#
#    part_num_len  color_name_len  part_name_len  is_ninjago
# 0             5               3             27           0
# 1             5               5             27           0
# 2             5               5             34           0
# 3             5               3             34           0
# 4             5               4             34           0

# %%
df.to_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone2/lego/df.csv', index=False)

# %%
df.shape
# Out:
# (580251, 21)

# %%
is_ninjago = df['is_ninjago'].sum() / df.shape[0]
is_ninjago
# Out:
# 0.029083965387392698
